# %%
pip install pandas openpyxl
# Out:
# Requirement already satisfied: pandas in c:\users\hp\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (2.3.1)
# Requirement already satisfied: openpyxl in c:\users\hp\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (3.1.5)
# Requirement already satisfied: numpy>=1.23.2 in c:\users\hp\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pandas) (2.1.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\hp\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\hp\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\hp\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pandas) (2025.2)
# Requirement already satisfied: et-xmlfile in c:\users\hp\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from openpyxl) (2.0.0)
# Requirement already satisfied: six>=1.5 in c:\users\hp\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 25.2
# [notice] To update, run: C:\Users\hp\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %% [markdown]
# # Importación de datos

# %%
import pandas as pd
import numpy as np  

# Cargar el archivo Excel
file_path = r'C:\Users\hp\Desktop\GIT HUB\REPOSITORIOS\Base Carabineros 2023\cuadros-estadísticas-policiales_cch_2023.xlsx'

# Leer todas las hojas del archivo Excel en un diccionario de DataFrames
df = pd.read_excel(file_path, sheet_name='10')

# Si quieres ver las primeras filas del archivo cargado
df.head()
# Out:
#   CUADRO 10: NÚMERO DE PERSONAS DETENIDAS/1 POR DÍA DE OCURRENCIA DEL DELITO Y SEXO, SEGÚN FAMILIA Y MATERIA, 2023  \
# 0                                             Código
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                101
#
#                      Unnamed: 1 Unnamed: 2       Unnamed: 3       Unnamed: 4  \
# 0             Familia y materia      Total  Total \nhombres  Total \nmujeres
# 1                           NaN        NaN              NaN              NaN
# 2                         Total     276677           224452            52225
# 3  QUEBRANTAMIENTO DE SENTENCIA        123              110               13
# 4               Quebrantamiento        123              110               13
#
#   Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9 Unnamed: 10  \
# 0      Lunes        NaN     Martes        NaN  Miércoles         NaN
# 1    Hombres    Mujeres    Hombres    Mujeres    Hombres     Mujeres
# 2      29695       6978      30655       7564      31859        7845
# 3         18          1         14          1         16           1
# 4         18          1         14          1         16           1
#
#   Unnamed: 11 Unnamed: 12 Unnamed: 13 Unnamed: 14 Unnamed: 15 Unnamed: 16  \
# 0      Jueves         NaN     Viernes         NaN      Sábado         NaN
# 1     Hombres     Mujeres     Hombres     Mujeres     Hombres     Mujeres
# 2       33033        8121       32428        7601       33151        7338
# 3          18           3          14           1          16           2
# 4          18           3          14           1          16           2
#
#   Unnamed: 17 Unnamed: 18
# 0     Domingo         NaN
# 1     Hombres     Mujeres
# 2       33631        6778
# 3          14           4
# 4          14           4

# %%
# Eliminar las columnas 'Unnamed: 2', 'Unnamed: 3' y 'Unnamed: 4'
df = df.drop(['Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4'], axis=1)
# Convertir la fila 0 en los nombres de columna y eliminar la fila 'head'
df.columns = df.iloc[0]
df = df.iloc[1:]

# %%
df
# Out:
# 0                                               Código  \
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  101
# 5                                                  NaN
# ..                                                 ...
# 324                                              18001
# 325  /1 El capítulo "Personas detenidas" incluye pe...
# 326  /2 Desde 2020, el registro de Violencia Intraf...
# 327  /3 Desde la publicación semestral 2023, se exc...
# 328                      Fuente: Carabineros de Chile.
#
# 0                                    Familia y materia    Lunes      NaN  \
# 1                                                  NaN  Hombres  Mujeres
# 2                                                Total    29695     6978
# 3                         QUEBRANTAMIENTO DE SENTENCIA       18        1
# 4                                      Quebrantamiento       18        1
# 5    CRÍMENES Y SIMPLES DELITOS QUE AFECTAN DERECHO...      308       67
# ..                                                 ...      ...      ...
# 324          Expendio de bebidas alcohólicas a menores        0        0
# 325                                                NaN      NaN      NaN
# 326                                                NaN      NaN      NaN
# 327                                                NaN      NaN      NaN
# 328                                                NaN      NaN      NaN
#
# 0     Martes      NaN Miércoles      NaN   Jueves      NaN  Viernes      NaN  \
# 1    Hombres  Mujeres   Hombres  Mujeres  Hombres  Mujeres  Hombres  Mujeres
# 2      30655     7564     31859     7845    33033     8121    32428     7601
# 3         14        1        16        1       18        3       14        1
# 4         14        1        16        1       18        3       14        1
# 5        268       57       256       54      270       53      277       48
# ..       ...      ...       ...      ...      ...      ...      ...      ...
# 324        0        1         0        0        1        1        2        2
# 325      NaN      NaN       NaN      NaN      NaN      NaN      NaN      NaN
# 326      NaN      NaN       NaN      NaN      NaN      NaN      NaN      NaN
# 327      NaN      NaN       NaN      NaN      NaN      NaN      NaN      NaN
# 328      NaN      NaN       NaN      NaN      NaN      NaN      NaN      NaN
#
# 0     Sábado      NaN  Domingo      NaN
# 1    Hombres  Mujeres  Hombres  Mujeres
# 2      33151     7338    33631     6778
# 3         16        2       14        4
# 4         16        2       14        4
# 5        358       41      407       60
# ..       ...      ...      ...      ...
# 324        5        3        4        1
# 325      NaN      NaN      NaN      NaN
# 326      NaN      NaN      NaN      NaN
# 327      NaN      NaN      NaN      NaN
# 328      NaN      NaN      NaN      NaN
#
# [328 rows x 16 columns]

# %% [markdown]
# # Nombrar Columnas NaN

# %%
# Nombrar columnas sin nombre con los dias
dias = ['Lun', 'Mar', 'Mié', 'Jue', 'Vie', 'Sáb', 'Dom']
sin_nombre = [i for i, col in enumerate(df.columns) if str(col).startswith('Unnamed') or col == '' or pd.isna(col)]
for idx, dia in zip(sin_nombre, dias):
    df.columns = [dia if i == idx else col for i, col in enumerate(df.columns)]

# %%
df.head()
# Out:
#   Código                                  Familia y materia    Lunes      Lun  \
# 1    NaN                                                NaN  Hombres  Mujeres
# 2    NaN                                              Total    29695     6978
# 3    NaN                       QUEBRANTAMIENTO DE SENTENCIA       18        1
# 4    101                                    Quebrantamiento       18        1
# 5    NaN  CRÍMENES Y SIMPLES DELITOS QUE AFECTAN DERECHO...      308       67
#
#     Martes      Mar Miércoles      Mié   Jueves      Jue  Viernes      Vie  \
# 1  Hombres  Mujeres   Hombres  Mujeres  Hombres  Mujeres  Hombres  Mujeres
# 2    30655     7564     31859     7845    33033     8121    32428     7601
# 3       14        1        16        1       18        3       14        1
# 4       14        1        16        1       18        3       14        1
# 5      268       57       256       54      270       53      277       48
#
#     Sábado      Sáb  Domingo      Dom
# 1  Hombres  Mujeres  Hombres  Mujeres
# 2    33151     7338    33631     6778
# 3       16        2       14        4
# 4       16        2       14        4
# 5      358       41      407       60

# %% [markdown]
# ## Crear columna Familia y rellenarla con data correspondiente

# %%
# Crear la columna 'Familia'
df['Familia'] = ''
# Rellenar la columna 'Familia' hacia abajo
df['Familia'] = df['Familia'].replace('', np.nan).ffill()
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_21724\2822500515.py:4: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['Familia'] = df['Familia'].replace('', np.nan).ffill()

# %%
# Reordenar columnas: 'Código', 'Familia', 'Familia y materia' como las tres primeras
cols = list(df.columns)
for col in ['Código', 'Familia', 'Familia y materia']:
    cols.remove(col)
df = df[['Código', 'Familia', 'Familia y materia'] + cols]

# %%
# Rellenar <NA> en 'Familia' con el valor de 'Familia y materia' cuando 'Código' es NaN
df.loc[df['Familia'].isna() & df['Código'].isna(), 'Familia'] = df.loc[df['Familia'].isna() & df['Código'].isna(), 'Familia y materia']
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_21724\2800418113.py:2: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[nan 'Total' 'QUEBRANTAMIENTO DE SENTENCIA'
#  'CRÍMENES Y SIMPLES DELITOS QUE AFECTAN DERECHOS GARANTIDOS POR LA CONSTITUCIÓN'
#  'CRÍMENES Y SIMPLES DELITOS CONTRA LA FE PÚBLICA, DE LAS FALSIFICACIONES, DEL FALSO TESTIMONIO Y DEL PERJURIO'
#  'CRÍMENES Y SIMPLES DELITOS COMETIDOS POR EMPLEADOS PÚBLICOS EN EL DESEMPEÑO DE SUS CARGOS'
#  'CRÍMENES Y SIMPLES DELITOS CONTRA EL ORDEN Y LA SEGURIDAD PÚBLICA COMETIDO POR PARTICULARES'
#  'CRÍMENES Y SIMPLES DELITOS CONTRA EL ORDEN DE LAS FAMILIAS, MORALIDAD PÚBLICA Y LA INTEGRIDAD SEXUAL'
#  'CRÍMENES Y SIMPLES DELITOS CONTRA LAS PERSONAS/2'
#  'CRÍMENES Y SIMPLES DELITOS CONTRA LA PROPIEDAD' 'DE LOS CUASIDELITOS'
#  'HECHOS DE RELEVANCIA CRIMINAL' 'DELITOS INFORMÁTICOS'
#  'LEY GENERAL DE BANCOS' 'LEY DE CUENTAS CORRIENTES BANCARIAS Y CHEQUES'
#  'DELITOS TRIBUTARIOS'
#  'TRÁFICO ILÍCITO DE ESTUPEFACIENTES Y SUSTANCIAS SICOTRÓPICAS'
#  'PROPIEDAD Y PRIVILEGIOS INDUSTRIALES' 'PROPIEDAD INTELECTUAL'
#  'CONTROL DE ARMAS. LEY 17.798; LEY 21.250'
#  'LEY ORGÁNICA DE INVESTIGACIONES' 'LEY ORGÁNICA DE GENDARMERÍA'
#  'LEY DE TRÁNSITO' 'INFRACCIÓN A OTROS TEXTOS LEGALES'
#  'SISTEMAS DE INSCRIPCIONES ELECTORALES Y SERVICIO ELECTORAL'
#  'CONDUCTAS TERRORISTAS' 'LIBERTAD DE OPINIÓN E INFORMACIÓN'
#  'VIOLENCIA INTRAFAMILIAR'
#  'INFRACCIONES A LA LEY DE DEFENSA DE LA LIBRE COMPETENCIA' 'FALTAS'
#  'FALTAS TRÁFICO ILÍCITO DE ESTUPEFACIENTES Y SUSTANCIAS SICOTRÓPICAS'
#  'FALTAS SOBRE EXPENDIO Y CONSUMO DE BEBIDAS ALCOHÓLICAS']' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[df['Familia'].isna() & df['Código'].isna(), 'Familia'] = df.loc[df['Familia'].isna() & df['Código'].isna(), 'Familia y materia']

# %%
# Reemplazar las filas vacías en 'Familia' con el valor de la fila anterior
df['Familia'] = df['Familia'].replace('', pd.NA)
df['Familia'] = df['Familia'].fillna(method='ffill') #Foward fill añade el valor de la fila anterior a las filas vacías
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_21724\4226272177.py:3: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df['Familia'] = df['Familia'].fillna(method='ffill') #Foward fill añade el valor de la fila anterior a las filas vacías

# %%
df
# Out:
#                                                 Código  \
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  101
# 5                                                  NaN
# ..                                                 ...
# 324                                              18001
# 325  /1 El capítulo "Personas detenidas" incluye pe...
# 326  /2 Desde 2020, el registro de Violencia Intraf...
# 327  /3 Desde la publicación semestral 2023, se exc...
# 328                      Fuente: Carabineros de Chile.
#
#                                                Familia  \
# 1                                                  NaN
# 2                                                Total
# 3                         QUEBRANTAMIENTO DE SENTENCIA
# 4                         QUEBRANTAMIENTO DE SENTENCIA
# 5    CRÍMENES Y SIMPLES DELITOS QUE AFECTAN DERECHO...
# ..                                                 ...
# 324  FALTAS SOBRE EXPENDIO Y CONSUMO DE BEBIDAS ALC...
# 325  FALTAS SOBRE EXPENDIO Y CONSUMO DE BEBIDAS ALC...
# 326  FALTAS SOBRE EXPENDIO Y CONSUMO DE BEBIDAS ALC...
# 327  FALTAS SOBRE EXPENDIO Y CONSUMO DE BEBIDAS ALC...
# 328  FALTAS SOBRE EXPENDIO Y CONSUMO DE BEBIDAS ALC...
#
#                                      Familia y materia    Lunes      Lun  \
# 1                                                  NaN  Hombres  Mujeres
# 2                                                Total    29695     6978
# 3                         QUEBRANTAMIENTO DE SENTENCIA       18        1
# 4                                      Quebrantamiento       18        1
# 5    CRÍMENES Y SIMPLES DELITOS QUE AFECTAN DERECHO...      308       67
# ..                                                 ...      ...      ...
# 324          Expendio de bebidas alcohólicas a menores        0        0
# 325                                                NaN      NaN      NaN
# 326                                                NaN      NaN      NaN
# 327                                                NaN      NaN      NaN
# 328                                                NaN      NaN      NaN
#
#       Martes      Mar Miércoles      Mié   Jueves      Jue  Viernes      Vie  \
# 1    Hombres  Mujeres   Hombres  Mujeres  Hombres  Mujeres  Hombres  Mujeres
# 2      30655     7564     31859     7845    33033     8121    32428     7601
# 3         14        1        16        1       18        3       14        1
# 4         14        1        16        1       18        3       14        1
# 5        268       57       256       54      270       53      277       48
# ..       ...      ...       ...      ...      ...      ...      ...      ...
# 324        0        1         0        0        1        1        2        2
# 325      NaN      NaN       NaN      NaN      NaN      NaN      NaN      NaN
# 326      NaN      NaN       NaN      NaN      NaN      NaN      NaN      NaN
# 327      NaN      NaN       NaN      NaN      NaN      NaN      NaN      NaN
# 328      NaN      NaN       NaN      NaN      NaN      NaN      NaN      NaN
#
#       Sábado      Sáb  Domingo      Dom
# 1    Hombres  Mujeres  Hombres  Mujeres
# 2      33151     7338    33631     6778
# 3         16        2       14        4
# 4         16        2       14        4
# 5        358       41      407       60
# ..       ...      ...      ...      ...
# 324        5        3        4        1
# 325      NaN      NaN      NaN      NaN
# 326      NaN      NaN      NaN      NaN
# 327      NaN      NaN      NaN      NaN
# 328      NaN      NaN      NaN      NaN
#
# [328 rows x 17 columns]

# %% [markdown]
# ### Resguardo división Hombre / Mujer

# %%
# Ingresar el valor 'Sexo' en la columna 'Código' en la fila 1
df.at[df.index[0], 'Código'] = 'Sexo'

# %%
df
# Out:
#                                                 Código  \
# 1                                                 Sexo
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  101
# 5                                                  NaN
# ..                                                 ...
# 324                                              18001
# 325  /1 El capítulo "Personas detenidas" incluye pe...
# 326  /2 Desde 2020, el registro de Violencia Intraf...
# 327  /3 Desde la publicación semestral 2023, se exc...
# 328                      Fuente: Carabineros de Chile.
#
#                                                Familia  \
# 1                                                  NaN
# 2                                                Total
# 3                         QUEBRANTAMIENTO DE SENTENCIA
# 4                         QUEBRANTAMIENTO DE SENTENCIA
# 5    CRÍMENES Y SIMPLES DELITOS QUE AFECTAN DERECHO...
# ..                                                 ...
# 324  FALTAS SOBRE EXPENDIO Y CONSUMO DE BEBIDAS ALC...
# 325  FALTAS SOBRE EXPENDIO Y CONSUMO DE BEBIDAS ALC...
# 326  FALTAS SOBRE EXPENDIO Y CONSUMO DE BEBIDAS ALC...
# 327  FALTAS SOBRE EXPENDIO Y CONSUMO DE BEBIDAS ALC...
# 328  FALTAS SOBRE EXPENDIO Y CONSUMO DE BEBIDAS ALC...
#
#                                      Familia y materia    Lunes      Lun  \
# 1                                                  NaN  Hombres  Mujeres
# 2                                                Total    29695     6978
# 3                         QUEBRANTAMIENTO DE SENTENCIA       18        1
# 4                                      Quebrantamiento       18        1
# 5    CRÍMENES Y SIMPLES DELITOS QUE AFECTAN DERECHO...      308       67
# ..                                                 ...      ...      ...
# 324          Expendio de bebidas alcohólicas a menores        0        0
# 325                                                NaN      NaN      NaN
# 326                                                NaN      NaN      NaN
# 327                                                NaN      NaN      NaN
# 328                                                NaN      NaN      NaN
#
#       Martes      Mar Miércoles      Mié   Jueves      Jue  Viernes      Vie  \
# 1    Hombres  Mujeres   Hombres  Mujeres  Hombres  Mujeres  Hombres  Mujeres
# 2      30655     7564     31859     7845    33033     8121    32428     7601
# 3         14        1        16        1       18        3       14        1
# 4         14        1        16        1       18        3       14        1
# 5        268       57       256       54      270       53      277       48
# ..       ...      ...       ...      ...      ...      ...      ...      ...
# 324        0        1         0        0        1        1        2        2
# 325      NaN      NaN       NaN      NaN      NaN      NaN      NaN      NaN
# 326      NaN      NaN       NaN      NaN      NaN      NaN      NaN      NaN
# 327      NaN      NaN       NaN      NaN      NaN      NaN      NaN      NaN
# 328      NaN      NaN       NaN      NaN      NaN      NaN      NaN      NaN
#
#       Sábado      Sáb  Domingo      Dom
# 1    Hombres  Mujeres  Hombres  Mujeres
# 2      33151     7338    33631     6778
# 3         16        2       14        4
# 4         16        2       14        4
# 5        358       41      407       60
# ..       ...      ...      ...      ...
# 324        5        3        4        1
# 325      NaN      NaN      NaN      NaN
# 326      NaN      NaN      NaN      NaN
# 327      NaN      NaN      NaN      NaN
# 328      NaN      NaN      NaN      NaN
#
# [328 rows x 17 columns]

# %% [markdown]
# ## Limpiar Filas NaN, correspondientes a sumas

# %%
# Eliminar filas donde 'Código' es NaN
df = df[df['Código'].notna()]

# %%
df
# Out:
#                                                 Código  \
# 1                                                 Sexo
# 4                                                  101
# 6                                                  202
# 7                                                  203
# 8                                                  204
# ..                                                 ...
# 324                                              18001
# 325  /1 El capítulo "Personas detenidas" incluye pe...
# 326  /2 Desde 2020, el registro de Violencia Intraf...
# 327  /3 Desde la publicación semestral 2023, se exc...
# 328                      Fuente: Carabineros de Chile.
#
#                                                Familia  \
# 1                                                  NaN
# 4                         QUEBRANTAMIENTO DE SENTENCIA
# 6    CRÍMENES Y SIMPLES DELITOS QUE AFECTAN DERECHO...
# 7    CRÍMENES Y SIMPLES DELITOS QUE AFECTAN DERECHO...
# 8    CRÍMENES Y SIMPLES DELITOS QUE AFECTAN DERECHO...
# ..                                                 ...
# 324  FALTAS SOBRE EXPENDIO Y CONSUMO DE BEBIDAS ALC...
# 325  FALTAS SOBRE EXPENDIO Y CONSUMO DE BEBIDAS ALC...
# 326  FALTAS SOBRE EXPENDIO Y CONSUMO DE BEBIDAS ALC...
# 327  FALTAS SOBRE EXPENDIO Y CONSUMO DE BEBIDAS ALC...
# 328  FALTAS SOBRE EXPENDIO Y CONSUMO DE BEBIDAS ALC...
#
#                              Familia y materia    Lunes      Lun   Martes  \
# 1                                          NaN  Hombres  Mujeres  Hombres
# 4                              Quebrantamiento       18        1       14
# 6                                    Secuestro       13        1       12
# 7                       Sustracción de menores        2        1        0
# 8                          Violación de morada      282       61      230
# ..                                         ...      ...      ...      ...
# 324  Expendio de bebidas alcohólicas a menores        0        0        0
# 325                                        NaN      NaN      NaN      NaN
# 326                                        NaN      NaN      NaN      NaN
# 327                                        NaN      NaN      NaN      NaN
# 328                                        NaN      NaN      NaN      NaN
#
#          Mar Miércoles      Mié   Jueves      Jue  Viernes      Vie   Sábado  \
# 1    Mujeres   Hombres  Mujeres  Hombres  Mujeres  Hombres  Mujeres  Hombres
# 4          1        16        1       18        3       14        1       16
# 6          1         5        2       19        1       18        2       11
# 7          0         2        0        1        0        0        0        2
# 8         51       218       49      217       44      238       41      313
# ..       ...       ...      ...      ...      ...      ...      ...      ...
# 324        1         0        0        1        1        2        2        5
# 325      NaN       NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 326      NaN       NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 327      NaN       NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 328      NaN       NaN      NaN      NaN      NaN      NaN      NaN      NaN
#
#          Sáb  Domingo      Dom
# 1    Mujeres  Hombres  Mujeres
# 4          2       14        4
# 6          1        9        2
# 7          2        2        0
# 8         32      369       51
# ..       ...      ...      ...
# 324        3        4        1
# 325      NaN      NaN      NaN
# 326      NaN      NaN      NaN
# 327      NaN      NaN      NaN
# 328      NaN      NaN      NaN
#
# [297 rows x 17 columns]

# %%
# Eliminar ultimas filas
df = df.iloc[:-4]

# %%
df
# Out:
#     Código                                            Familia  \
# 1     Sexo                                                NaN
# 4      101                       QUEBRANTAMIENTO DE SENTENCIA
# 6      202  CRÍMENES Y SIMPLES DELITOS QUE AFECTAN DERECHO...
# 7      203  CRÍMENES Y SIMPLES DELITOS QUE AFECTAN DERECHO...
# 8      204  CRÍMENES Y SIMPLES DELITOS QUE AFECTAN DERECHO...
# ..     ...                                                ...
# 318  13101                                             FALTAS
# 319  13103                                             FALTAS
# 321   7038  FALTAS TRÁFICO ILÍCITO DE ESTUPEFACIENTES Y SU...
# 322   7039  FALTAS TRÁFICO ILÍCITO DE ESTUPEFACIENTES Y SU...
# 324  18001  FALTAS SOBRE EXPENDIO Y CONSUMO DE BEBIDAS ALC...
#
#                                      Familia y materia    Lunes      Lun  \
# 1                                                  NaN  Hombres  Mujeres
# 4                                      Quebrantamiento       18        1
# 6                                            Secuestro       13        1
# 7                               Sustracción de menores        2        1
# 8                                  Violación de morada      282       61
# ..                                                 ...      ...      ...
# 318   Transporte de desechos a vertederos clandestinos        0        0
# 319         Perro potencialmente peligroso no inscrito        0        0
# 321  Consumo o porte en lugares públicos o privados...      404       36
# 322   Consumo o porte de drogas en lugares calificados       35        6
# 324          Expendio de bebidas alcohólicas a menores        0        0
#
#       Martes      Mar Miércoles      Mié   Jueves      Jue  Viernes      Vie  \
# 1    Hombres  Mujeres   Hombres  Mujeres  Hombres  Mujeres  Hombres  Mujeres
# 4         14        1        16        1       18        3       14        1
# 6         12        1         5        2       19        1       18        2
# 7          0        0         2        0        1        0        0        0
# 8        230       51       218       49      217       44      238       41
# ..       ...      ...       ...      ...      ...      ...      ...      ...
# 318        0        0         0        0        1        0        0        0
# 319        0        0         0        0        1        0        0        1
# 321      485       51       441       57      473       37      403       47
# 322       45       10        44        2       47       12       35        9
# 324        0        1         0        0        1        1        2        2
#
#       Sábado      Sáb  Domingo      Dom
# 1    Hombres  Mujeres  Hombres  Mujeres
# 4         16        2       14        4
# 6         11        1        9        2
# 7          2        2        2        0
# 8        313       32      369       51
# ..       ...      ...      ...      ...
# 318        0        0        0        0
# 319        0        1        0        0
# 321      241       24      179       26
# 322       27        3       24        3
# 324        5        3        4        1
#
# [293 rows x 17 columns]

# %% [markdown]
# ## Separar información Hombres y Mujeres

# %%
# Separar columnas según los valores 'Hombres' y 'Mujeres' en la fila 0
columnas_fijas = ['Código', 'Familia', 'Familia y materia']
hombres_cols = columnas_fijas + [col for col in df.columns if df.iloc[0][col] == 'Hombres']
mujeres_cols = columnas_fijas + [col for col in df.columns if df.iloc[0][col] == 'Mujeres']
hombres_df = df[hombres_cols]
mujeres_df = df[mujeres_cols]

mujeres_df
# Out:
#     Código                                            Familia  \
# 1     Sexo                                                NaN
# 4      101                       QUEBRANTAMIENTO DE SENTENCIA
# 6      202  CRÍMENES Y SIMPLES DELITOS QUE AFECTAN DERECHO...
# 7      203  CRÍMENES Y SIMPLES DELITOS QUE AFECTAN DERECHO...
# 8      204  CRÍMENES Y SIMPLES DELITOS QUE AFECTAN DERECHO...
# ..     ...                                                ...
# 318  13101                                             FALTAS
# 319  13103                                             FALTAS
# 321   7038  FALTAS TRÁFICO ILÍCITO DE ESTUPEFACIENTES Y SU...
# 322   7039  FALTAS TRÁFICO ILÍCITO DE ESTUPEFACIENTES Y SU...
# 324  18001  FALTAS SOBRE EXPENDIO Y CONSUMO DE BEBIDAS ALC...
#
#                                      Familia y materia      Lun      Mar  \
# 1                                                  NaN  Mujeres  Mujeres
# 4                                      Quebrantamiento        1        1
# 6                                            Secuestro        1        1
# 7                               Sustracción de menores        1        0
# 8                                  Violación de morada       61       51
# ..                                                 ...      ...      ...
# 318   Transporte de desechos a vertederos clandestinos        0        0
# 319         Perro potencialmente peligroso no inscrito        0        0
# 321  Consumo o porte en lugares públicos o privados...       36       51
# 322   Consumo o porte de drogas en lugares calificados        6       10
# 324          Expendio de bebidas alcohólicas a menores        0        1
#
#          Mié      Jue      Vie      Sáb      Dom
# 1    Mujeres  Mujeres  Mujeres  Mujeres  Mujeres
# 4          1        3        1        2        4
# 6          2        1        2        1        2
# 7          0        0        0        2        0
# 8         49       44       41       32       51
# ..       ...      ...      ...      ...      ...
# 318        0        0        0        0        0
# 319        0        0        1        1        0
# 321       57       37       47       24       26
# 322        2       12        9        3        3
# 324        0        1        2        3        1
#
# [293 rows x 10 columns]

# %%
hombres_df
# Out:
#     Código                                            Familia  \
# 1     Sexo                                                NaN
# 4      101                       QUEBRANTAMIENTO DE SENTENCIA
# 6      202  CRÍMENES Y SIMPLES DELITOS QUE AFECTAN DERECHO...
# 7      203  CRÍMENES Y SIMPLES DELITOS QUE AFECTAN DERECHO...
# 8      204  CRÍMENES Y SIMPLES DELITOS QUE AFECTAN DERECHO...
# ..     ...                                                ...
# 318  13101                                             FALTAS
# 319  13103                                             FALTAS
# 321   7038  FALTAS TRÁFICO ILÍCITO DE ESTUPEFACIENTES Y SU...
# 322   7039  FALTAS TRÁFICO ILÍCITO DE ESTUPEFACIENTES Y SU...
# 324  18001  FALTAS SOBRE EXPENDIO Y CONSUMO DE BEBIDAS ALC...
#
#                                      Familia y materia    Lunes   Martes  \
# 1                                                  NaN  Hombres  Hombres
# 4                                      Quebrantamiento       18       14
# 6                                            Secuestro       13       12
# 7                               Sustracción de menores        2        0
# 8                                  Violación de morada      282      230
# ..                                                 ...      ...      ...
# 318   Transporte de desechos a vertederos clandestinos        0        0
# 319         Perro potencialmente peligroso no inscrito        0        0
# 321  Consumo o porte en lugares públicos o privados...      404      485
# 322   Consumo o porte de drogas en lugares calificados       35       45
# 324          Expendio de bebidas alcohólicas a menores        0        0
#
#     Miércoles   Jueves  Viernes   Sábado  Domingo
# 1     Hombres  Hombres  Hombres  Hombres  Hombres
# 4          16       18       14       16       14
# 6           5       19       18       11        9
# 7           2        1        0        2        2
# 8         218      217      238      313      369
# ..        ...      ...      ...      ...      ...
# 318         0        1        0        0        0
# 319         0        1        0        0        0
# 321       441      473      403      241      179
# 322        44       47       35       27       24
# 324         0        1        2        5        4
#
# [293 rows x 10 columns]

# %%
# Renombrar columnas de mujeres_df con meses completos en español, mayúscula inicial y sin tildes
dias_completos = ['Lunes', 'Martes', 'Miércoles', 'Jueves', 'Viernes', 'Sábado', 'Domingo']
mujeres_df = mujeres_df.rename(columns=dict(zip(dias, dias_completos)))
mujeres_df
# Out:
#     Código                                            Familia  \
# 1     Sexo                                                NaN
# 4      101                       QUEBRANTAMIENTO DE SENTENCIA
# 6      202  CRÍMENES Y SIMPLES DELITOS QUE AFECTAN DERECHO...
# 7      203  CRÍMENES Y SIMPLES DELITOS QUE AFECTAN DERECHO...
# 8      204  CRÍMENES Y SIMPLES DELITOS QUE AFECTAN DERECHO...
# ..     ...                                                ...
# 318  13101                                             FALTAS
# 319  13103                                             FALTAS
# 321   7038  FALTAS TRÁFICO ILÍCITO DE ESTUPEFACIENTES Y SU...
# 322   7039  FALTAS TRÁFICO ILÍCITO DE ESTUPEFACIENTES Y SU...
# 324  18001  FALTAS SOBRE EXPENDIO Y CONSUMO DE BEBIDAS ALC...
#
#                                      Familia y materia    Lunes   Martes  \
# 1                                                  NaN  Mujeres  Mujeres
# 4                                      Quebrantamiento        1        1
# 6                                            Secuestro        1        1
# 7                               Sustracción de menores        1        0
# 8                                  Violación de morada       61       51
# ..                                                 ...      ...      ...
# 318   Transporte de desechos a vertederos clandestinos        0        0
# 319         Perro potencialmente peligroso no inscrito        0        0
# 321  Consumo o porte en lugares públicos o privados...       36       51
# 322   Consumo o porte de drogas en lugares calificados        6       10
# 324          Expendio de bebidas alcohólicas a menores        0        1
#
#     Miércoles   Jueves  Viernes   Sábado  Domingo
# 1     Mujeres  Mujeres  Mujeres  Mujeres  Mujeres
# 4           1        3        1        2        4
# 6           2        1        2        1        2
# 7           0        0        0        2        0
# 8          49       44       41       32       51
# ..        ...      ...      ...      ...      ...
# 318         0        0        0        0        0
# 319         0        0        1        1        0
# 321        57       37       47       24       26
# 322         2       12        9        3        3
# 324         0        1        2        3        1
#
# [293 rows x 10 columns]

# %%
# Renombrar columna 'Familia y materia' como 'Materia' en ambos DataFrames
hombres_df = hombres_df.rename(columns={'Familia y materia': 'Materia'})
mujeres_df = mujeres_df.rename(columns={'Familia y materia': 'Materia'})
hombres_df
# Out:
#     Código                                            Familia  \
# 1     Sexo                                                NaN
# 4      101                       QUEBRANTAMIENTO DE SENTENCIA
# 6      202  CRÍMENES Y SIMPLES DELITOS QUE AFECTAN DERECHO...
# 7      203  CRÍMENES Y SIMPLES DELITOS QUE AFECTAN DERECHO...
# 8      204  CRÍMENES Y SIMPLES DELITOS QUE AFECTAN DERECHO...
# ..     ...                                                ...
# 318  13101                                             FALTAS
# 319  13103                                             FALTAS
# 321   7038  FALTAS TRÁFICO ILÍCITO DE ESTUPEFACIENTES Y SU...
# 322   7039  FALTAS TRÁFICO ILÍCITO DE ESTUPEFACIENTES Y SU...
# 324  18001  FALTAS SOBRE EXPENDIO Y CONSUMO DE BEBIDAS ALC...
#
#                                                Materia    Lunes   Martes  \
# 1                                                  NaN  Hombres  Hombres
# 4                                      Quebrantamiento       18       14
# 6                                            Secuestro       13       12
# 7                               Sustracción de menores        2        0
# 8                                  Violación de morada      282      230
# ..                                                 ...      ...      ...
# 318   Transporte de desechos a vertederos clandestinos        0        0
# 319         Perro potencialmente peligroso no inscrito        0        0
# 321  Consumo o porte en lugares públicos o privados...      404      485
# 322   Consumo o porte de drogas en lugares calificados       35       45
# 324          Expendio de bebidas alcohólicas a menores        0        0
#
#     Miércoles   Jueves  Viernes   Sábado  Domingo
# 1     Hombres  Hombres  Hombres  Hombres  Hombres
# 4          16       18       14       16       14
# 6           5       19       18       11        9
# 7           2        1        0        2        2
# 8         218      217      238      313      369
# ..        ...      ...      ...      ...      ...
# 318         0        1        0        0        0
# 319         0        1        0        0        0
# 321       441      473      403      241      179
# 322        44       47       35       27       24
# 324         0        1        2        5        4
#
# [293 rows x 10 columns]

# %%
# Eliminar fila donde 'Código' == 'Sexo' en ambos DataFrames
hombres_df = hombres_df[hombres_df['Código'] != 'Sexo']
mujeres_df = mujeres_df[mujeres_df['Código'] != 'Sexo']
# Crear columna 'Sexo' en ambos DataFrames
hombres_df["Sexo"] = "Hombres"
mujeres_df["Sexo"] = "Mujeres"
hombres_df
mujeres_df
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_21724\3025596638.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   hombres_df["Sexo"] = "Hombres"
#     Código                                            Familia  \
# 4      101                       QUEBRANTAMIENTO DE SENTENCIA
# 6      202  CRÍMENES Y SIMPLES DELITOS QUE AFECTAN DERECHO...
# 7      203  CRÍMENES Y SIMPLES DELITOS QUE AFECTAN DERECHO...
# 8      204  CRÍMENES Y SIMPLES DELITOS QUE AFECTAN DERECHO...
# 9      205  CRÍMENES Y SIMPLES DELITOS QUE AFECTAN DERECHO...
# ..     ...                                                ...
# 318  13101                                             FALTAS
# 319  13103                                             FALTAS
# 321   7038  FALTAS TRÁFICO ILÍCITO DE ESTUPEFACIENTES Y SU...
# 322   7039  FALTAS TRÁFICO ILÍCITO DE ESTUPEFACIENTES Y SU...
# 324  18001  FALTAS SOBRE EXPENDIO Y CONSUMO DE BEBIDAS ALC...
#
#                                                Materia Lunes Martes Miércoles  \
# 4                                      Quebrantamiento     1      1         1
# 6                                            Secuestro     1      1         2
# 7                               Sustracción de menores     1      0         0
# 8                                  Violación de morada    61     51        49
# 9    Apertura, registro o interceptación de corresp...     0      0         0
# ..                                                 ...   ...    ...       ...
# 318   Transporte de desechos a vertederos clandestinos     0      0         0
# 319         Perro potencialmente peligroso no inscrito     0      0         0
# 321  Consumo o porte en lugares públicos o privados...    36     51        57
# 322   Consumo o porte de drogas en lugares calificados     6     10         2
# 324          Expendio de bebidas alcohólicas a menores     0      1         0
#
#     Jueves Viernes Sábado Domingo     Sexo
# 4        3       1      2       4  Mujeres
# 6        1       2      1       2  Mujeres
# 7        0       0      2       0  Mujeres
# 8       44      41     32      51  Mujeres
# 9        0       0      0       0  Mujeres
# ..     ...     ...    ...     ...      ...
# 318      0       0      0       0  Mujeres
# 319      0       1      1       0  Mujeres
# 321     37      47     24      26  Mujeres
# 322     12       9      3       3  Mujeres
# 324      1       2      3       1  Mujeres
#
# [292 rows x 11 columns]

# %%
# Unir ambos DataFrames correctamente y fijar columnas
DetGenDia_df = pd.concat([hombres_df, mujeres_df], ignore_index=True)
columnas_fijas = ['Código', 'Familia', 'Materia', 'Sexo']
otras_columnas = [col for col in DetGenDia_df.columns if col not in columnas_fijas]
DetGenDia_df = DetGenDia_df[columnas_fijas + otras_columnas]
DetGenDia_df
# Out:
#     Código                                            Familia  \
# 0      101                       QUEBRANTAMIENTO DE SENTENCIA
# 1      202  CRÍMENES Y SIMPLES DELITOS QUE AFECTAN DERECHO...
# 2      203  CRÍMENES Y SIMPLES DELITOS QUE AFECTAN DERECHO...
# 3      204  CRÍMENES Y SIMPLES DELITOS QUE AFECTAN DERECHO...
# 4      205  CRÍMENES Y SIMPLES DELITOS QUE AFECTAN DERECHO...
# ..     ...                                                ...
# 579  13101                                             FALTAS
# 580  13103                                             FALTAS
# 581   7038  FALTAS TRÁFICO ILÍCITO DE ESTUPEFACIENTES Y SU...
# 582   7039  FALTAS TRÁFICO ILÍCITO DE ESTUPEFACIENTES Y SU...
# 583  18001  FALTAS SOBRE EXPENDIO Y CONSUMO DE BEBIDAS ALC...
#
#                                                Materia     Sexo Lunes Martes  \
# 0                                      Quebrantamiento  Hombres    18     14
# 1                                            Secuestro  Hombres    13     12
# 2                               Sustracción de menores  Hombres     2      0
# 3                                  Violación de morada  Hombres   282    230
# 4    Apertura, registro o interceptación de corresp...  Hombres     0      1
# ..                                                 ...      ...   ...    ...
# 579   Transporte de desechos a vertederos clandestinos  Mujeres     0      0
# 580         Perro potencialmente peligroso no inscrito  Mujeres     0      0
# 581  Consumo o porte en lugares públicos o privados...  Mujeres    36     51
# 582   Consumo o porte de drogas en lugares calificados  Mujeres     6     10
# 583          Expendio de bebidas alcohólicas a menores  Mujeres     0      1
#
#     Miércoles Jueves Viernes Sábado Domingo
# 0          16     18      14     16      14
# 1           5     19      18     11       9
# 2           2      1       0      2       2
# 3         218    217     238    313     369
# 4           0      0       0      0       0
# ..        ...    ...     ...    ...     ...
# 579         0      0       0      0       0
# 580         0      0       1      1       0
# 581        57     37      47     24      26
# 582         2     12       9      3       3
# 583         0      1       2      3       1
#
# [584 rows x 11 columns]

# %% [markdown]
# # Exportar a CSV

# %%
DetGenDia_df.to_csv(r'C:\Users\hp\Desktop\GIT HUB\REPOSITORIOS\Base Carabineros 2023\CSV_DATA\DetGenDia_df.csv', index=False)
